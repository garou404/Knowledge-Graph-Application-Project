# %%
import pandas as pd
import os
from bs4 import BeautifulSoup
import requests
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import random
import json

# %%
df_players = pd.read_csv("./data/processed/df_players.csv")
df_champions = pd.read_csv("./data/processed/df_champions.csv")

# %% [markdown]
# Roles

# %%
content_roles = """"""

for role in list(df_players['Pos'].unique()):
    content_roles += f"""
    <!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{role} -->

    <owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{role}">
        <rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{role}"/>
        <untitled-ontology-22:roleName>{role}</untitled-ontology-22:roleName>
    </owl:NamedIndividual>
    
    
    """

print(content_roles)
# Out:
#     <!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Toplane -->
#
#     <owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Toplane">
#         <rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Toplane"/>
#         <untitled-ontology-22:roleName>Toplane</untitled-ontology-22:roleName>
#     </owl:NamedIndividual>
#
#
#
#     <!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Botlane -->
#
#     <owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Botlane">
#         <rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Botlane"/>
#         <untitled-ontology-22:roleName>Botlane</untitled-ontology-22:roleName>
#     </owl:NamedIndividual>
#
#
#
# ...

# %%
content_faction = """"""

for faction in list(df_champions['Region'].unique()):
    content_faction += f"""
    <!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{faction.replace(' ', '_').replace('\'', '')} -->

    <owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{faction.replace(' ', '_').replace('\'', '')}">
        <rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Faction"/>
        <untitled-ontology-22:factionName>{faction}</untitled-ontology-22:factionName>
    </owl:NamedIndividual>
    
    
    """

print(content_faction)
# Out:
#     <!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Unknown -->
#
#     <owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Unknown">
#         <rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Faction"/>
#         <untitled-ontology-22:factionName>Unknown</untitled-ontology-22:factionName>
#     </owl:NamedIndividual>
#
#
#
#     <!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Ionia -->
#
#     <owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Ionia">
#         <rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Faction"/>
#         <untitled-ontology-22:factionName>Ionia</untitled-ontology-22:factionName>
#     </owl:NamedIndividual>
#
#
#
# ...

# %%
df_teams = df_players[['Team', 'Region', 'Year']].groupby(['Team', 'Region', 'Year']).count().reset_index()
df_teams = df_teams.groupby(['Team', 'Region'])['Year'].apply(list).reset_index()
df_teams
for index, row in df_teams.iterrows():
    print(row['Team'], row['Region'])
    [print(i) for i in row['Year']]
    print()
# Out:
# Anyone's Legend LPL
# 2024
# 2025
#
# BNK FEARX LCK
# 2024
# 2025
#
# Bilibili Gaming LPL
# 2024
# 2025
#
# DN Freecs LCK
# 2024
# 2025
#
# DRX LCK
# 2024
# 2025
#
# Dplus KIA LCK
# 2024
# 2025
#
# EDward Gaming LPL
# 2024
# 2025
#
# Fnatic LEC
# 2024
# 2025
#
# FunPlus Phoenix LPL
# 2024
# 2025
#
# G2 Esports LEC
# 2024
# 2025
#
# Gen.G LCK
# 2024
# 2025
#
# GiantX LEC
# 2024
# 2025
#
# Hanwha Life Esports LCK
# 2024
# 2025
#
# Invictus Gaming LPL
# 2024
# 2025
#
# JD Gaming LPL
# 2024
# 2025
#
# KT Rolster LCK
# 2024
# 2025
#
# Karmine Corp LEC
# 2024
# 2025
#
# LGD Gaming LPL
# 2024
# 2025
#
# LNG Esports LPL
# 2024
# 2025
#
# MAD Lions KOI LEC
# 2024
#
# Movistar KOI LEC
# 2025
#
# Ninjas in Pyjamas LPL
# 2024
# 2025
#
# Nongshim RedForce LCK
# 2024
# 2025
#
# OKSavingsBank BRION LCK
# 2024
# 2025
#
# Oh My God LPL
# 2024
# 2025
#
# Rare Atom LPL
# 2024
#
# Rogue LEC
# 2024
# 2025
#
# Royal Never Give Up LPL
# 2024
# 2025
#
# SK Gaming LEC
# 2024
# 2025
#
# T1 LCK
# 2024
# 2025
# ...

# %%
teams_content = """"""

for index, row in df_teams.iterrows():
    # print(row['Team'], row['Region'])
    teams_content += f"""
<!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{row['Team'].replace(' ', '_').replace('\'', '')} -->    
    
<owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{row['Team'].replace(' ', '_').replace('\'', '')}">
    <rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Team"/>"""
    for year in row['Year']:
        teams_content += f"""
    <untitled-ontology-22:hasRoster rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{row['Team'].replace(' ', '_').replace('\'', '')}_{year}"/>"""
    teams_content += f"""
    <untitled-ontology-22:region>{row['Region']}</untitled-ontology-22:region>
    <untitled-ontology-22:teamName>{row['Team']}</untitled-ontology-22:teamName>
</owl:NamedIndividual>
    
    """

print(teams_content)
# Out:
# <!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Anyones_Legend -->
#
# <owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Anyones_Legend">
#     <rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Team"/>
#     <untitled-ontology-22:hasRoster rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Anyones_Legend_2024"/>
#     <untitled-ontology-22:hasRoster rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Anyones_Legend_2025"/>
#     <untitled-ontology-22:region>LPL</untitled-ontology-22:region>
#     <untitled-ontology-22:teamName>Anyone's Legend</untitled-ontology-22:teamName>
# </owl:NamedIndividual>
#
#
# <!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#BNK_FEARX -->
#
# ...

# %% [markdown]
# Roster

# %%
df_roster = df_players[['Team','Year', 'Player']].groupby(['Team', 'Year', 'Player']).count().reset_index()
df_roster = df_roster.groupby(['Team', 'Year'])['Player'].apply(list).reset_index()
df_roster
# Out:
#                Team  Year                                        Player
# 0   Anyone's Legend  2024              [Ale, Croco, Hope, Kael, Shanks]
# 1   Anyone's Legend  2025         [Flandre, Hope, Kael, Shanks, Tarzan]
# 2         BNK FEARX  2024  [Clear, Clozer, Duro, Execute, Hena, Raptor]
# 3         BNK FEARX  2025        [Clear, Diable, Kellin, Raptor, VicLa]
# 4   Bilibili Gaming  2024              [Bin, Elk, ON, Wei, Xun, knight]
# ..              ...   ...                                           ...
# 68      Top Esports  2025       [369, Creme, Crisp, JackeyLove, Kanavi]
# 69      Ultra Prime  2024      [Doggo, H4cker, Niket, Qingtian, Yuekai]
# 70      Ultra Prime  2025      [1Jiang, Junhao, Rosielove, Saber, Wako]
# 71     Weibo Gaming  2024       [Breathe, Crisp, Light, Tarzan, Xiaohu]
# 72     Weibo Gaming  2025          [Breathe, Hang, Light, Tian, Xiaohu]
#
# [73 rows x 3 columns]

# %%
roster_content = """"""

for index, row in df_roster.iterrows():
	roster_content += f"""
<!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{row['Team'].replace(' ', '_').replace('\'', '')}_{row['Year']} -->

<owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{row['Team'].replace(' ', '_').replace('\'', '')}_{row['Year']}">
    <rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Roster"/>"""
	for i in row['Player']:
		roster_content += f"""
        <untitled-ontology-22:hasPlayer rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{i.replace(' ', '_').replace('\'', '')}"/>"""

	roster_content += f"""
	<untitled-ontology-22:rosterYear rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">{row['Year']}</untitled-ontology-22:rosterYear>
</owl:NamedIndividual>

"""
print(roster_content)
# Out:
# <!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Anyones_Legend_2024 -->
#
# <owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Anyones_Legend_2024">
#     <rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Roster"/>
#         <untitled-ontology-22:hasPlayer rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Ale"/>
#         <untitled-ontology-22:hasPlayer rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Croco"/>
#         <untitled-ontology-22:hasPlayer rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Hope"/>
#         <untitled-ontology-22:hasPlayer rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Kael"/>
# ...

# %% [markdown]
# Champions

# %%
def ttl(str_format):
    return str_format.replace(' ', '_').replace('\'', '')
ttl("Kha'Zix")
# Out:
# 'KhaZix'

# %%
champions_content = """"""

	# champions_content += f"""
for index, row in df_champions.iterrows():
	champions_content += f"""<!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{ttl(row['Champion'])} -->

<owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{ttl(row['Champion'])}">
	<rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Champion"/>
	<untitled-ontology-22:hasFaction rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{ttl(row['Region'])}"/>
	<untitled-ontology-22:hasPrimaryRole rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{row['role']}"/>"""
	
	if type(row['Player']) == str:
		for player in row['Player'][1:-1].split(','):
			my_player = player.replace("'", "").strip()
			champions_content += f"""
	<untitled-ontology-22:isPlayedBy rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{my_player.replace(' ', '_').replace('\'', '')}"/>"""	
	

	champions_content += f"""
	<untitled-ontology-22:abilityPower rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">{0}</untitled-ontology-22:abilityPower>
	<untitled-ontology-22:armor rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">{round(row['armor'])}</untitled-ontology-22:armor>
	<untitled-ontology-22:attackDamage rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">{round(row['attackDamage'])}</untitled-ontology-22:attackDamage>
	<untitled-ontology-22:attackSpeed rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">{round(row['attackSpeed'])}</untitled-ontology-22:attackSpeed>
	<untitled-ontology-22:championName>{row['Champion']}</untitled-ontology-22:championName>
	<untitled-ontology-22:healthPoints rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">{round(row['healthPoints'])}</untitled-ontology-22:healthPoints>
	<untitled-ontology-22:magicResist rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">{round(row['magicResist'])}</untitled-ontology-22:magicResist>
	<untitled-ontology-22:movementSpeed rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">{round(row['movementSpeed'])}</untitled-ontology-22:movementSpeed>
	<untitled-ontology-22:resourceType>{row['ressourceType']}</untitled-ontology-22:resourceType>
</owl:NamedIndividual>
	
	"""

print(champions_content)
# Out:
# <!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Aatrox -->
#
# <owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Aatrox">
# 	<rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Champion"/>
# 	<untitled-ontology-22:hasFaction rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Unknown"/>
# 	<untitled-ontology-22:hasPrimaryRole rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Support"/>
# 	<untitled-ontology-22:isPlayedBy rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Way"/>
# 	<untitled-ontology-22:abilityPower rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0</untitled-ontology-22:abilityPower>
# 	<untitled-ontology-22:armor rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">38</untitled-ontology-22:armor>
# ...

# %% [markdown]
# Players

# %%
df_players.loc[df_players['Team'] == 'T1']
# Out:
#        Player Team      Pos Region  Year  Nationality          Champion
# 80      Faker   T1  Midlane    LCK  2025      unknown             Galio
# 96      Doran   T1  Toplane    LCK  2025      unknown             Brand
# 101  Gumayusi   T1  Botlane    LCK  2025  South Korea              Bard
# 106     Keria   T1  Support    LCK  2025  South Korea          Bel'Veth
# 114      Oner   T1   Jungle    LCK  2025  South Korea        Tryndamere
# 125     Smash   T1  Botlane    LCK  2025      unknown        Tahm Kench
# 134     Faker   T1  Midlane    LCK  2024      unknown              Sion
# 161  Gumayusi   T1  Botlane    LCK  2024  South Korea  Nunu and Willump
# 166     Keria   T1  Support    LCK  2024  South Korea              Hwei
# 176      Oner   T1   Jungle    LCK  2024  South Korea             Elise
# 198      Zeus   T1  Toplane    LCK  2024  South Korea              Gnar

# %%
player_content = """"""

for index, row in df_players.iterrows():
    player_content += f"""
<!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{ttl(row['Player'])} -->

<owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{ttl(row['Player'])}">
	<rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Player"/>
	<untitled-ontology-22:playsInRoster rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{ttl(row['Team'])}_{row['Year']}"/>
	<untitled-ontology-22:playsMostly rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{ttl(row['Champion'])}"/>
	<untitled-ontology-22:hasPrimaryRole rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#{row['Pos']}"/>
	<untitled-ontology-22:nationality>{row['Nationality']}</untitled-ontology-22:nationality>
	<untitled-ontology-22:summonerName>{row['Player']}</untitled-ontology-22:summonerName>
</owl:NamedIndividual>

"""
print(player_content)
# Out:
# <!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#1Jiang -->
#
# <owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#1Jiang">
# 	<rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Player"/>
# 	<untitled-ontology-22:playsInRoster rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Ultra_Prime_2025"/>
# 	<untitled-ontology-22:playsMostly rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Malzahar"/>
# 	<untitled-ontology-22:hasPrimaryRole rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Toplane"/>
# 	<untitled-ontology-22:nationality>Taiwan</untitled-ontology-22:nationality>
# 	<untitled-ontology-22:summonerName>1Jiang</untitled-ontology-22:summonerName>
# </owl:NamedIndividual>
#
#
# ...

# %%
df_champions.loc[df_champions['Champion'].str.contains('Skaarl')]
# Out:
#            Champion Region  healthPoints  attackDamage  attackSpeed  armor  \
# 67  Kled and Skaarl  Noxus           810            65        0.625   35.0
#
#     magicResist  movementSpeed ressourceType     role     Player
# 67         28.0            345          mana  Midlane  ['Vladi']

# %%
with open("graph/individuals.txt", "w") as text_file:
    text_file.write(champions_content+player_content+roster_content+teams_content+content_roles+content_faction)

# %%
content = """

   <!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#ADC -->

    <owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#ADC">
        <rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Botlane"/>
        <untitled-ontology-22:roleName>Botlane</untitled-ontology-22:roleName>
    </owl:NamedIndividual>
    


    <!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Caliste -->

    <owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Caliste">
        <rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Player"/>
        <untitled-ontology-22:playsMostly rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Yasuo"/>
        <untitled-ontology-22:nationality>French</untitled-ontology-22:nationality>
        <untitled-ontology-22:summonerName>Caliste</untitled-ontology-22:summonerName>
    </owl:NamedIndividual>
    


    <!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Ionia -->

    <owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Ionia">
        <rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Faction"/>
        <untitled-ontology-22:factionName>Ionia</untitled-ontology-22:factionName>
    </owl:NamedIndividual>
    


    <!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Karmine_Corp -->

    <owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Karmine_Corp">
        <rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Team"/>
        <untitled-ontology-22:hasRoster rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Karmine_Corp_2025"/>
        <untitled-ontology-22:region>LEC</untitled-ontology-22:region>
        <untitled-ontology-22:teamName>Karmine Corp</untitled-ontology-22:teamName>
    </owl:NamedIndividual>
    


    <!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Karmine_Corp_2025 -->

    <owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Karmine_Corp_2025">
        <rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Roster"/>
        <untitled-ontology-22:hasPlayer rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Caliste"/>
        <untitled-ontology-22:rosterYear rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">2025</untitled-ontology-22:rosterYear>
    </owl:NamedIndividual>
    


    <!-- http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Yasuo -->

    <owl:NamedIndividual rdf:about="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Yasuo">
        <rdf:type rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Champion"/>
        <untitled-ontology-22:hasFaction rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Ionia"/>
        <untitled-ontology-22:hasPrimaryRole rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#ADC"/>
        <untitled-ontology-22:isPlayedBy rdf:resource="http://www.semanticweb.org/charles-m/ontologies/2025/1/untitled-ontology-22#Caliste"/>
        <untitled-ontology-22:abilityPower rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">0</untitled-ontology-22:abilityPower>
        <untitled-ontology-22:armor rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">30</untitled-ontology-22:armor>
        <untitled-ontology-22:attackDamage rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">100</untitled-ontology-22:attackDamage>
        <untitled-ontology-22:attackSpeed rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">50</untitled-ontology-22:attackSpeed>
        <untitled-ontology-22:championName>Yasuo</untitled-ontology-22:championName>
        <untitled-ontology-22:healthPoints rdf:datatype="http://www.w3.org/2001/XMLSchema#integer">400</untitled-ontology-22:healthPoints>
        <untitled-ontology-22:magicResist rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">50</untitled-ontology-22:magicResist>
        <untitled-ontology-22:movementSpeed rdf:datatype="http://www.w3.org/2001/XMLSchema#decimal">60</untitled-ontology-22:movementSpeed>
        <untitled-ontology-22:resourceType>mana</untitled-ontology-22:resourceType>
    </owl:NamedIndividual>"""
